# %% [markdown]
# ### RNN with Attention (Possible solution)

# %%
# -*- coding: utf-8 -*-
"""
Wind Turbine Power Prediction with RNNs + Attention

This lab uses an Attention-enhanced Recurrent Neural Network to predict wind turbine power output.
"""

# Step 0: Load libraries & Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Layer
from tensorflow.keras.callbacks import EarlyStopping
import math

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Step 1: Prepare the Data
df = pd.read_csv('T1.csv')
df['Date/Time'] = pd.to_datetime(df['Date/Time'], format="%d %m %Y %H:%M", dayfirst=True)
df = df.dropna()

# Quick EDA
print(df.describe())
plt.scatter(df['Wind Speed (m/s)'], df['LV ActivePower (kW)'])
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('LV ActivePower (kW)')
plt.title('Wind Speed vs Active Power')
plt.show()
# Out:
#                            Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# count                          50530         50530.000000      50530.000000
# mean   2018-07-01 20:01:30.065307648          1307.684332          7.557952
# min              2018-01-01 00:00:00            -2.471405          0.000000
# 25%              2018-04-03 05:22:30            50.677890          4.201395
# 50%              2018-06-30 16:15:00           825.838074          7.104594
# 75%              2018-09-26 18:57:30          2482.507568         10.300020
# max              2018-12-31 23:50:00          3618.732910         25.206011
# std                              NaN          1312.459242          4.227166
#
#        Theoretical_Power_Curve (KWh)  Wind Direction (°)
# count                   50530.000000        50530.000000
# mean                     1492.175463          123.687559
# min                         0.000000            0.000000
# 25%                       161.328167           49.315437
# 50%                      1063.776283           73.712978
# 75%                      2964.972462          201.696720
# max                      3600.000000          359.997589
# std                      1368.018238           93.443736

# %%
# Step 2: Create sequences
features = ['LV ActivePower (kW)', 'Wind Speed (m/s)', 'Theoretical_Power_Curve (KWh)']
data=df[features].values

#Normalize
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

print(df['Date/Time'].head(10)) 
interval = df.index.to_series().diff().dropna()
print(interval.value_counts())
seq_length = 24 # 24hrs x 6 samples(every 10 min)

def create_sequences(data, seq_length):
    """
    Turns a 2D array (samples x features) into a 3D array of sliding windows (samples x seq_length x features)
    and a 2D array of next-step targets (samples x features).
    
    Parameters:
    -----------
    data : np.ndarray
        Scaled dataset, shape = (num_samples, num_features)
    seq_length : int
        Length of each input sequence (number of time steps)
    
    Returns:
    --------
    X : np.ndarray
        Input sequences, shape = (num_sequences, seq_length, num_features)
    y : np.ndarray
        Corresponding next values, shape = (num_sequences, num_features) or (num_sequences,) if single target
    """
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length][0])  # Predict LV ActivePower
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_data, seq_length)

print(X.shape)
print(y.shape)
# Out:
# 0   2018-01-01 00:00:00
# 1   2018-01-01 00:10:00
# 2   2018-01-01 00:20:00
# 3   2018-01-01 00:30:00
# 4   2018-01-01 00:40:00
# 5   2018-01-01 00:50:00
# 6   2018-01-01 01:00:00
# 7   2018-01-01 01:10:00
# 8   2018-01-01 01:20:00
# 9   2018-01-01 01:30:00
# Name: Date/Time, dtype: datetime64[ns]
# 1.0    50529
# Name: count, dtype: int64
# (50506, 24, 3)
# (50506,)

# %%
# Step 3: Split the data
train_size = int(len(X) * 0.8)

X_train, X_test = X[:train_size], X[train_size:]

y_train, y_test = y[:train_size], y[train_size:]

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (40404, 24, 3)
# X_test shape: (10102, 24, 3)
# y_train shape: (40404,)
# y_test shape: (10102,)

# %%
# Step 4: Define a Custom Attention Layer
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)
    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], input_shape[-1]), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[-1],), initializer="zeros")
        super(AttentionLayer, self).build(input_shape)
    def call(self, inputs):
        score = tf.tanh(tf.matmul(inputs, self.W) + self.b)
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = attention_weights * inputs
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector

# %%
# Step 5: Build the RNN Model with Attention
inputs = Input(shape=(seq_length, len(features)))
x = LSTM(64, return_sequences=True)(inputs)
x = Dropout(0.2)(x)
x = LSTM(32, return_sequences=True)(x)
x = Dropout(0.2)(x)
context_vector = AttentionLayer()(x)
output = Dense(1)(context_vector)
model = Model(inputs, output)
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 24, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 24, 64)         │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 24, 32)         │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 24, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_layer                 │ (None, 32)             │         1,056 │
# │ (AttentionLayer)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,913 (120.75 KB)
#  Trainable params: 30,913 (120.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Step 6: Compile and Train the Model
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop]
)

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

# Step 7: Evaluate and Visualize the Results
y_pred = model.predict(X_test)
# Inverse transform predictions and targets for metrics
y_test_rescaled = scaler.inverse_transform(np.concatenate([y_test.reshape(-1,1), np.zeros((y_test.shape[0], data.shape[1]-1))], axis=1))[:,0]
y_pred_rescaled = scaler.inverse_transform(np.concatenate([y_pred, np.zeros((y_pred.shape[0], data.shape[1]-1))], axis=1))[:,0]

mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mse)
r2 = r2_score(y_test_rescaled, y_pred_rescaled)
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.4f}")
# Out:
# Epoch 1/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0311 - val_loss: 0.0084
# Epoch 2/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0107 - val_loss: 0.0050
# Epoch 3/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0076 - val_loss: 0.0049
# Epoch 4/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0068 - val_loss: 0.0048
# Epoch 5/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0067 - val_loss: 0.0055
# Epoch 6/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0064 - val_loss: 0.0046
# Epoch 7/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0060 - val_loss: 0.0047
# Epoch 8/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0061 - val_loss: 0.0044
# Epoch 9/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0059 - val_loss: 0.0045
# Epoch 10/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0059 - val_loss: 0.0047
# Epoch 11/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 12/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 13/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 14/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 15/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0056 - val_loss: 0.0045
# Epoch 16/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0055 - val_loss: 0.0044
# Epoch 17/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 18/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 19/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 20/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 21/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 22/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 23/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 24/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 25/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 26/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 27/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 28/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 29/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 30/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 31/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 32/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 33/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0043
# Epoch 34/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 35/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 36/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0052 - val_loss: 0.0044
# Epoch 37/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 38/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 39/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 40/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 41/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 42/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 43/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 44/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0051 - val_loss: 0.0042
# Epoch 45/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 46/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 47/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 48/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 49/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 50/50
# 1011/1011 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0049 - val_loss: 0.0042
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# RMSE: 230.83
# R²: 0.9704

# %%
# Visualize attention weights 
plt.figure(figsize=(15, 5))
plt.plot(y_test_rescaled, label='Actual', linewidth=2, color='blue')
plt.plot(y_pred_rescaled, label='Predicted', linewidth=2, color='orange', alpha=0.7)
plt.xlabel('Time Step')
plt.ylabel('Power Output (kW)')
plt.title('Actual vs Predicted Power Output')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 6))
plt.scatter(y_test_rescaled, y_pred_rescaled, alpha=0.5)
plt.plot([min(y_test_rescaled), max(y_test_rescaled)],
         [min(y_test_rescaled), max(y_test_rescaled)], 'r--', linewidth=2, label='Ideal Fit')
plt.xlabel('Actual Power Output (kW)')
plt.ylabel('Predicted Power Output (kW)')
plt.title('Actual vs Predicted Scatter Plot')
plt.legend()
plt.tight_layout()
plt.show()
