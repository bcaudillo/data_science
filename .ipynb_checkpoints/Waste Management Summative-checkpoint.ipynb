# %% [markdown]
# # EcoSort Waste Management Assistant
# # Module 8 Summative Lab

# %% [markdown]
# ## Overview
#
# You are a data scientist at "EcoSort," a technology company that specializes in developing AI solutions for waste management. EcoSort has partnered with Metro City's waste management department to develop an intelligent waste management assistant that can help residents properly dispose of waste items so less time is spent sorting material at facilities.
#
# This assistant needs to:
#
# 1. Identify waste materials from images uploaded by residents (CNN)
# 2. Classify waste items based on text descriptions provided by residents (RNN/Transformer)
# 3. Generate specific recycling instructions based on identified waste type and city policies (Generative Transformer with RAG)
#
# Your task is to build this integrated system using the RealWaste dataset along with generated text data that simulates real-world waste management operations.

# %% [markdown]
# ## Part 1: Dataset Exploration and Preparation
#
# In this section, you will explore and prepare the datasets for your models.

# %% [markdown]
# ### 1.1 Load and Explore the RealWaste Dataset

# %%
# Import necessary libraries
import os
import re
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import json
from sklearn.feature_extraction.text import TfidfVectorizer
import random
from sentence_transformers import SentenceTransformer
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, regularizers
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer
from transformers import TFBertForSequenceClassification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import layers, regularizers, Model, Sequential




# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
# TODO: Load and explore the RealWaste dataset
# - Dataset structure
# - Distribution of waste categories
# - Image characteristics (resolution, quality, background)

df = pd.read_csv("Waste Descriptions.csv")
print("Dataset columns:", df.columns.tolist())
print(df.head(3))
# Out:
# Dataset columns: ['description', 'category', 'disposal_instruction', 'common_confusion', 'material_composition']
#                                          description       category  \
# 0                           soiled silver tablecloth  Textile Trash
# 1                        folded glass bottle leaking          Glass
# 2  large Supermarket vegetable waste with food re...  Food Organics
#
#                                 disposal_instruction common_confusion  \
# 0  Look for textile recycling programs in your area.              NaN
# 1     Remove caps, lids, and corks before recycling.              NaN
# 2   If no compost available, place in general waste.              NaN
#
#                                 material_composition
# 0  Fabric made from natural or synthetic fibers, ...
# 1  Silica-based material, may contain additives f...
# 2  Biodegradable matter derived from plant or ani...

# %% [markdown]
# ### 1.2 Explore Text Datasets

# %%
# TODO: Load and explore the waste description text data
# - Load waste_descriptions.csv
# - Analyze vocabulary and structure
# - Understand the distribution of categories
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# Load your waste_descriptions.csv
df = pd.read_csv('Waste Descriptions.csv')

# Analyze category distribution
print("\nCategory distribution:")
print(df['category'].value_counts())
plt.figure(figsize=(8,4))
sns.countplot(data=df, x="category", order=df['category'].value_counts().index)
plt.title("Waste Category Distribution")
plt.xlabel("Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Find all images inside subfolders (recursively)
image_dir = "./realwaste-main/RealWaste"
image_files = []
category_counts = {}

if os.path.exists(image_dir):
    for root, dirs, files in os.walk(image_dir):
        for f in files:
            if f.lower().endswith(('.jpg', '.png', '.jpeg')):
                full_path = os.path.join(root, f)
                image_files.append(full_path)
                # Track counts per category (folder name)
                category = os.path.basename(root)
                category_counts[category] = category_counts.get(category, 0) + 1

    print(f"\nNumber of image files: {len(image_files)}")
    print("Image count per category:", category_counts)

    # Check a sample of image sizes
    widths, heights = [], []
    for img_path in image_files[:50]:  # sample first 50 images
        try:
            with Image.open(img_path) as img:
                w, h = img.size
                widths.append(w)
                heights.append(h)
        except Exception as e:
            print(f"Error reading {img_path}: {e}")

    if widths and heights:
        print("Image resolution (sample):")
        print("  Mean width:", np.mean(widths), "Mean height:", np.mean(heights))
        print("  Min width:", np.min(widths), "Max width:", np.max(widths))
        plt.figure(figsize=(8,4))
        plt.hist(widths, bins=20, alpha=0.7, label='Width')
        plt.hist(heights, bins=20, alpha=0.7, label='Height')
        plt.title("Image Resolution Distribution (Sample)")
        plt.xlabel("Pixels")
        plt.ylabel("Count")
        plt.legend()
        plt.show()
    else:
        print("No image sizes to display (files might be corrupted or unreadable).")
else:
    print("Image directory not found. Skipping image resolution analysis.")
# Out:
# Category distribution:
# category
# Vegetation             600
# Textile Trash          586
# Cardboard              584
# Miscellaneous Trash    578
# Plastic                569
# Glass                  551
# Food Organics          518
# Metal                  508
# Paper                  506
# Name: count, dtype: int64
# Number of image files: 4752
# Image count per category: {'Paper': 500, 'Metal': 790, 'Cardboard': 461, 'Food Organics': 411, 'Glass': 420, 'Vegetation': 436, 'Textile Trash': 318, 'Miscellaneous Trash': 495, 'Plastic': 921}
# Image resolution (sample):
#   Mean width: 524.0 Mean height: 524.0
#   Min width: 524 Max width: 524

# %%
# TODO: Load and explore the waste policy documents
# - Load waste_policy_documents.csv
# - Understand document organization and language


policy_df = pd.read_csv('./Waste Descriptions.csv')
print("Columns:", policy_df.columns.tolist())
print(policy_df.head())

print(policy_df.columns.tolist())
print(policy_df.head())
# Out:
# Columns: ['description', 'category', 'disposal_instruction', 'common_confusion', 'material_composition']
#                                          description       category  \
# 0                           soiled silver tablecloth  Textile Trash
# 1                        folded glass bottle leaking          Glass
# 2  large Supermarket vegetable waste with food re...  Food Organics
# 3                         intact floral carpet piece  Textile Trash
# 4                  empty fun-sized purple apple core  Food Organics
#
#                                 disposal_instruction  \
# 0  Look for textile recycling programs in your area.
# 1     Remove caps, lids, and corks before recycling.
# 2   If no compost available, place in general waste.
# 3  Look for textile recycling programs in your area.
# 4           Keep separate from recyclable materials.
#
#                                     common_confusion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Meat and dairy products may be restricted in s...
#
#                                 material_composition
# 0  Fabric made from natural or synthetic fibers, ...
# 1  Silica-based material, may contain additives f...
# 2  Biodegradable matter derived from plant or ani...
# 3  Fabric made from natural or synthetic fibers, ...
# 4  Biodegradable matter derived from plant or ani...
# ['description', 'category', 'disposal_instruction', 'common_confusion', 'material_composition']
#                                          description       category  \
# 0                           soiled silver tablecloth  Textile Trash
# 1                        folded glass bottle leaking          Glass
# 2  large Supermarket vegetable waste with food re...  Food Organics
# 3                         intact floral carpet piece  Textile Trash
# 4                  empty fun-sized purple apple core  Food Organics
#
#                                 disposal_instruction  \
# 0  Look for textile recycling programs in your area.
# 1     Remove caps, lids, and corks before recycling.
# 2   If no compost available, place in general waste.
# 3  Look for textile recycling programs in your area.
# 4           Keep separate from recyclable materials.
#
#                                     common_confusion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Meat and dairy products may be restricted in s...
#
#                                 material_composition
# 0  Fabric made from natural or synthetic fibers, ...
# 1  Silica-based material, may contain additives f...
# 2  Biodegradable matter derived from plant or ani...
# 3  Fabric made from natural or synthetic fibers, ...
# 4  Biodegradable matter derived from plant or ani...

# %% [markdown]
# ### 1.3 Create Data Pipelines

# %%
import pathlib

# Parameters
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224

data_dir = pathlib.Path('./realwaste-main/RealWaste')
class_names = sorted([item.name for item in data_dir.glob('*') if item.is_dir()])
num_classes = len(class_names)

# Data split
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    label_mode='categorical'
)

# Split val_ds in half to create a test set
val_batches = tf.data.experimental.cardinality(val_ds)
test_ds = val_ds.take(val_batches // 2)
val_ds = val_ds.skip(val_batches // 2)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Data augmentation
data_augmentation = Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
], name="augmentation")

# Build the model
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)
)
base_model.trainable = True  

inputs = layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation='softmax', kernel_regularizer=regularizers.l2(0.01))(x)

model = Model(inputs, outputs)

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',  # label_mode='categorical'
    metrics=['accuracy']
)

early_stopping = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate
val_loss, val_acc = model.evaluate(val_ds)
print(f"Validation Accuracy: {val_acc:.4f}, Validation Loss: {val_loss:.4f}")

test_loss, test_acc = model.evaluate(test_ds)
print(f"Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}")
# Out:
# Found 4752 files belonging to 9 classes.
# Using 3802 files for training.
# Found 4752 files belonging to 9 classes.
# Using 950 files for validation.
# Epoch 1/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 252s 2s/step - accuracy: 0.2889 - loss: 2.1059 - val_accuracy: 0.6468 - val_loss: 1.1757 - learning_rate: 1.0000e-04
# Epoch 2/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.6977 - loss: 1.0985 - val_accuracy: 0.7213 - val_loss: 0.9394 - learning_rate: 1.0000e-04
# Epoch 3/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2423s 21s/step - accuracy: 0.8055 - loss: 0.7714 - val_accuracy: 0.7468 - val_loss: 0.8798 - learning_rate: 1.0000e-04
# Epoch 4/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1156s 10s/step - accuracy: 0.8788 - loss: 0.5706 - val_accuracy: 0.7638 - val_loss: 0.8201 - learning_rate: 1.0000e-04
# Epoch 5/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1178s 10s/step - accuracy: 0.8985 - loss: 0.4917 - val_accuracy: 0.7766 - val_loss: 0.7564 - learning_rate: 1.0000e-04
# Epoch 6/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1253s 11s/step - accuracy: 0.9344 - loss: 0.4008 - val_accuracy: 0.7979 - val_loss: 0.7350 - learning_rate: 1.0000e-04
# Epoch 7/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2131s 18s/step - accuracy: 0.9450 - loss: 0.3477 - val_accuracy: 0.8170 - val_loss: 0.6495 - learning_rate: 1.0000e-04
# Epoch 8/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.9643 - loss: 0.2892 - val_accuracy: 0.8298 - val_loss: 0.6376 - learning_rate: 1.0000e-04
# Epoch 9/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2177s 18s/step - accuracy: 0.9676 - loss: 0.2617 - val_accuracy: 0.8404 - val_loss: 0.6132 - learning_rate: 1.0000e-04
# Epoch 10/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 477s 4s/step - accuracy: 0.9762 - loss: 0.2308 - val_accuracy: 0.8362 - val_loss: 0.6294 - learning_rate: 1.0000e-04
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 245ms/step - accuracy: 0.8611 - loss: 0.5677
# Validation Accuracy: 0.8404, Validation Loss: 0.6132
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 261ms/step - accuracy: 0.8487 - loss: 0.6112
# Test Accuracy: 0.8604, Test Loss: 0.6097

# %%
# TODO: Create a text preprocessing pipeline
# - Tokenization
# - Text cleaning
# - Split data into train and test
# - Create embeddings/features

# Load the text data
text_df = pd.read_csv("./Waste Descriptions.csv")
print("Columns:", text_df.columns)
print(text_df.head(2))

# Clean up the description text (lowercase, remove punctuation, collapse spaces)
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

text_col = 'description'
label_col = 'category'
text_df[text_col] = text_df[text_col].apply(clean_text)

# Encode the waste categories as numbers for modeling
class_names = sorted(text_df[label_col].unique())
class_map = {c: i for i, c in enumerate(class_names)}
text_df['label'] = text_df[label_col].map(class_map)

# Split the dataset into training and testing sets (stratified by label)
train_df, test_df = train_test_split(
    text_df, test_size=0.2, stratify=text_df['label'], random_state=42)
print(f"Train size: {len(train_df)}, Test size: {len(test_df)}")

# Extract text features using TF-IDF
vectorizer = TfidfVectorizer(
    max_features=1000,
    stop_words='english'
)
X_train = vectorizer.fit_transform(train_df[text_col])
X_test = vectorizer.transform(test_df[text_col])
y_train = train_df['label'].values
y_test = test_df['label'].values

print("TF-IDF feature shape:", X_train.shape)

# Optional: Train a simple classifier (here, logistic regression)
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
print("Text Classifier Test Accuracy:", clf.score(X_test, y_test))
# Out:
# Columns: Index(['description', 'category', 'disposal_instruction', 'common_confusion',
#        'material_composition'],
#       dtype='object')
#                    description       category  \
# 0     soiled silver tablecloth  Textile Trash
# 1  folded glass bottle leaking          Glass
#
#                                 disposal_instruction common_confusion  \
# 0  Look for textile recycling programs in your area.              NaN
# 1     Remove caps, lids, and corks before recycling.              NaN
#
#                                 material_composition
# 0  Fabric made from natural or synthetic fibers, ...
# 1  Silica-based material, may contain additives f...
# Train size: 4000, Test size: 1000
# TF-IDF feature shape: (4000, 300)
# Text Classifier Test Accuracy: 0.997

# %%
# TODO: Prepare documents for RAG
# - Document preprocessing
# - Create embeddings for retrieval

policy_df = pd.read_json("./Waste Policy Documents.json")

def clean_doc(text):
    # Lowercase, remove non-alphanumerics except space
    text = str(text).lower()
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

policy_df['clean_text'] = policy_df['document_text'].apply(clean_doc)
embedding_model = SentenceTransformer("all-mpnet-base-v2")  # You can swap for another model if needed

print("Generating embeddings...")
policy_embeddings = embedding_model.encode(policy_df['clean_text'].tolist(), show_progress_bar=True)

print("Embeddings shape:", policy_embeddings.shape)

documents = policy_df['clean_text'].tolist()
metadata  = policy_df.to_dict(orient='records')
# Out:
# Generating embeddings...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Embeddings shape: (14, 768)

# %% [markdown]
# ## Part 2: Waste Material Classification with CNN
#
# In this section, you will build a CNN model to classify waste materials from images.

# %% [markdown]
# ### 2.1 Preprocess Images

# %%
# TODO: Implement image preprocessing

# Set image parameters (based on model requirements or dataset)
IMG_SIZE = (224, 224)   # Change if your model expects something different
BATCH_SIZE = 32

# Directory where your images are stored in subfolders by class
data_dir = './realwaste-main/RealWaste'  

# Split train/val/test using image_dataset_from_directory
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='training',
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset='validation',
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

# Normalize pixel values (0-1) as a preprocessing step for CNN
normalization_layer = tf.keras.layers.Rescaling(1./255)

# Optionally add augmentation (recommended for training!)
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

# Apply to dataset (map applies the transformation batch-wise)
train_ds = train_ds.map(lambda x, y: (normalization_layer(data_augmentation(x)), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# Prefetch for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# Peek at a batch (sanity check)
import matplotlib.pyplot as plt

images, labels = next(iter(train_ds))
plt.figure(figsize=(12, 6))
for i in range(8):
    plt.subplot(2, 4, i + 1)
    plt.imshow(images[i].numpy())
    plt.title(f"Label: {labels[i].numpy()}")
    plt.axis('off')
plt.suptitle("Example Preprocessed Images")
plt.show()
# Out:
# Found 4752 files belonging to 9 classes.
# Using 3802 files for training.
# Found 4752 files belonging to 9 classes.
# Using 950 files for validation.

# %% [markdown]
# ### 2.2 Implement CNN Model with Transfer Learning

# %%
# TODO: Select an appropriate base model and implement transfer learning
# - Choose from MobileNet, EfficientNet, etc.
# - Add custom classification layers for the 9 waste categories
# - Configure loss function and metrics
from tensorflow import keras
from tensorflow.keras import layers, regularizers

def create_transfer_model(
    img_size=(224, 224),
    num_classes=9,
    base_model_name='EfficientNetB0', 
    dropout_rate=0.3,
    learning_rate=1e-4,
    l2_strength=0.01,
    train_base=False
):
    # Load base model
    base_model_class = getattr(keras.applications, base_model_name)
    base_model = base_model_class(
        input_shape=img_size + (3,),
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = train_base  # Freeze during initial training

    # Build classification head
    inputs = keras.Input(shape=img_size + (3,))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=regularizers.l2(l2_strength)
    )(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs, outputs)

    # Compile
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss='sparse_categorical_crossentropy',  # assuming integer labels
        metrics=['accuracy', keras.metrics.Precision()]
    )
    
    return model

# Create the model
cnn_model = create_transfer_model()
cnn_model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_5      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,214,700 (16.08 MB)
#  Trainable params: 165,129 (645.04 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %% [markdown]
# ### 2.3 Train and Evaluate the Model

# %%
# TODO: Train the CNN model
# - Use appropriate batch size and epochs
# - Implement regularization to prevent overfitting
# - Monitor training and validation metrics
from tensorflow import keras
from tensorflow.keras import layers, regularizers

def create_transfer_model(
    img_size=(224, 224),
    num_classes=9,
    base_model_name='EfficientNetB0',
    dropout_rate=0.3,
    learning_rate=1e-4,
    train_base=False,
    l2_strength=0.01
):
    # Load pre-trained base model without top
    base_model_class = getattr(keras.applications, base_model_name)
    base_model = base_model_class(
        input_shape=img_size + (3,),
        include_top=False,
        weights='imagenet'
    )
    base_model.trainable = train_base  # Freeze base initially

    # Build the model
    inputs = keras.Input(shape=img_size + (3,))
    x = base_model(inputs, training=False)  # Important: training=False to avoid batchnorm update if frozen
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=regularizers.l2(l2_strength)
    )(x)
    outputs = layers.Dense(
        num_classes,
        activation='softmax',
        kernel_regularizer=regularizers.l2(l2_strength)
    )(x)

    model = keras.Model(inputs, outputs)

    # Compile for one-hot encoded labels
    model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision()]
)


    return model

# Instantiate the model
model = create_transfer_model()

for image_batch, label_batch in train_ds.take(1):
    print("Image batch shape:", image_batch.shape)  # Expect: (batch_size, 224, 224, 3)
    print("Label batch shape:", label_batch.shape)  # Expect: (batch_size,)
    print("Label example:", label_batch[:5].numpy())  # Should be integers
# Out:
# Image batch shape: (32, 224, 224, 3)
# Label batch shape: (32,)
# Label example: [5 1 6 4 8]

# %%
# TODO: Evaluate model performance
# - Calculate accuracy on test set
# - Generate confusion matrix
# - Analyze error patterns
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Constants
NUM_CLASSES = 9
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
TEST_DIR = "./realwaste-main/realwaste" 

# Load test dataset from directory
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=False  # So order of predictions matches labels
)

# Store class names for later
class_names = test_ds.class_names

# Prefetch for performance
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)


# Generate predictions and collect true labels
y_true, y_pred = [], []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# Found 4752 files belonging to 9 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 775ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 836ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 2025-06-29 09:12:23.097991: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Classification Report:
#                      precision    recall  f1-score   support
#
#           Cardboard       0.12      0.12      0.12       461
#       Food Organics       0.00      0.00      0.00       411
#               Glass       0.08      0.07      0.07       420
#               Metal       0.13      0.23      0.16       790
# Miscellaneous Trash       0.06      0.07      0.07       495
#               Paper       0.19      0.25      0.21       500
#             Plastic       0.27      0.02      0.04       921
#       Textile Trash       0.02      0.01      0.01       318
#          Vegetation       0.05      0.11      0.07       436
#
#            accuracy                           0.11      4752
#           macro avg       0.10      0.10      0.08      4752
#        weighted avg       0.12      0.11      0.09      4752

# %% [markdown]
# ### 2.4 Fine-tune the Model

# %%
# TODO: Tune model parameters to improve performance
# - Adjust learning rate
# - Add regularization, dropout
# - Modify architecture if needed
# Data augmentation pipeline
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential, regularizers
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Data augmentation pipeline
data_augmentation = Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.15),
], name="augmentation")

# Build base model
base_model = EfficientNetB0(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3)
)
base_model.trainable = False  # Freeze for transfer learning phase

inputs = layers.Input(shape=(224, 224, 3), name='input_image')
x = layers.Rescaling(1./255)(inputs)
x = data_augmentation(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
outputs = layers.Dense(9, activation='softmax', kernel_regularizer=regularizers.l2(0.01))(x)
model = Model(inputs, outputs, name="EffNet_transfer")

# Initial compile (transfer learning phase)
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6, verbose=1)

# Train (transfer learning)
EPOCHS = 10
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[early_stopping, reduce_lr]
)

# Fine-tuning: unfreeze the *last 50 layers* of the base model for further training
base_model.trainable = True
for layer in base_model.layers[:-50]:
    layer.trainable = False

# Re-compile with a *lower* learning rate
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Continue training (fine-tuning)
history_finetune = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15,
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate on validation set
val_loss, val_acc = model.evaluate(val_ds)
print(f"Validation Accuracy: {val_acc:.4f}, Validation Loss: {val_loss:.4f}")
# Out:
# Epoch 1/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 58s 464ms/step - accuracy: 0.1642 - loss: 4.5489 - val_accuracy: 0.1884 - val_loss: 4.1609 - learning_rate: 1.0000e-04
# Epoch 2/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 57s 475ms/step - accuracy: 0.1761 - loss: 4.0844 - val_accuracy: 0.1884 - val_loss: 3.7767 - learning_rate: 1.0000e-04
# Epoch 3/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 56s 469ms/step - accuracy: 0.1756 - loss: 3.7200 - val_accuracy: 0.1884 - val_loss: 3.4754 - learning_rate: 1.0000e-04
# Epoch 4/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 56s 469ms/step - accuracy: 0.1813 - loss: 3.4313 - val_accuracy: 0.1884 - val_loss: 3.2347 - learning_rate: 1.0000e-04
# Epoch 5/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 57s 480ms/step - accuracy: 0.1792 - loss: 3.2008 - val_accuracy: 0.1884 - val_loss: 3.0441 - learning_rate: 1.0000e-04
# Epoch 6/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 56s 473ms/step - accuracy: 0.1828 - loss: 3.0156 - val_accuracy: 0.1884 - val_loss: 2.8913 - learning_rate: 1.0000e-04
# Epoch 7/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 56s 473ms/step - accuracy: 0.1906 - loss: 2.8722 - val_accuracy: 0.1884 - val_loss: 2.7682 - learning_rate: 1.0000e-04
# Epoch 8/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 57s 475ms/step - accuracy: 0.1889 - loss: 2.7574 - val_accuracy: 0.1884 - val_loss: 2.6721 - learning_rate: 1.0000e-04
# Epoch 9/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 56s 467ms/step - accuracy: 0.1873 - loss: 2.6600 - val_accuracy: 0.1884 - val_loss: 2.5917 - learning_rate: 1.0000e-04
# Epoch 10/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 56s 471ms/step - accuracy: 0.1866 - loss: 2.5820 - val_accuracy: 0.1884 - val_loss: 2.5264 - learning_rate: 1.0000e-04
# Epoch 1/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 78s 596ms/step - accuracy: 0.1602 - loss: 2.5389 - val_accuracy: 0.1884 - val_loss: 2.4661 - learning_rate: 1.0000e-04
# Epoch 2/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 73s 609ms/step - accuracy: 0.1908 - loss: 2.4659 - val_accuracy: 0.1884 - val_loss: 2.4137 - learning_rate: 1.0000e-04
# Epoch 3/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 73s 613ms/step - accuracy: 0.1844 - loss: 2.4188 - val_accuracy: 0.1884 - val_loss: 2.3746 - learning_rate: 1.0000e-04
# Epoch 4/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 74s 622ms/step - accuracy: 0.1844 - loss: 2.3762 - val_accuracy: 0.1884 - val_loss: 2.3342 - learning_rate: 1.0000e-04
# Epoch 5/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 77s 650ms/step - accuracy: 0.1859 - loss: 2.3347 - val_accuracy: 0.1884 - val_loss: 2.3050 - learning_rate: 1.0000e-04
# Epoch 6/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 76s 634ms/step - accuracy: 0.1881 - loss: 2.3068 - val_accuracy: 0.1884 - val_loss: 2.2793 - learning_rate: 1.0000e-04
# Epoch 7/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 449s 4s/step - accuracy: 0.1875 - loss: 2.2841 - val_accuracy: 0.1884 - val_loss: 2.2585 - learning_rate: 1.0000e-04
# Epoch 8/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 270s 2s/step - accuracy: 0.1875 - loss: 2.2657 - val_accuracy: 0.1884 - val_loss: 2.2414 - learning_rate: 1.0000e-04
# Epoch 9/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 54s 457ms/step - accuracy: 0.1886 - loss: 2.2468 - val_accuracy: 0.1884 - val_loss: 2.2283 - learning_rate: 1.0000e-04
# Epoch 10/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 60s 506ms/step - accuracy: 0.1862 - loss: 2.2349 - val_accuracy: 0.1884 - val_loss: 2.2161 - learning_rate: 1.0000e-04
# Epoch 11/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 59s 492ms/step - accuracy: 0.1874 - loss: 2.2260 - val_accuracy: 0.1884 - val_loss: 2.2058 - learning_rate: 1.0000e-04
# Epoch 12/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 61s 515ms/step - accuracy: 0.1865 - loss: 2.2169 - val_accuracy: 0.1884 - val_loss: 2.1976 - learning_rate: 1.0000e-04
# Epoch 13/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 72s 605ms/step - accuracy: 0.1898 - loss: 2.2040 - val_accuracy: 0.1884 - val_loss: 2.1902 - learning_rate: 1.0000e-04
# Epoch 14/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 70s 589ms/step - accuracy: 0.1845 - loss: 2.2016 - val_accuracy: 0.1884 - val_loss: 2.1851 - learning_rate: 1.0000e-04
# Epoch 15/15
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 72s 601ms/step - accuracy: 0.1908 - loss: 2.1915 - val_accuracy: 0.1884 - val_loss: 2.1795 - learning_rate: 1.0000e-04
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 361ms/step - accuracy: 0.1843 - loss: 2.1834
# Validation Accuracy: 0.1884, Validation Loss: 2.1795

# %%
# Plot training curves
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
if 'accuracy' in history_finetune.history:
    plt.plot(history_finetune.history['accuracy'], label='Fine-tune Train Acc')
    plt.plot(history_finetune.history['val_accuracy'], label='Fine-tune Val Acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
if 'loss' in history_finetune.history:
    plt.plot(history_finetune.history['loss'], label='Fine-tune Train Loss')
    plt.plot(history_finetune.history['val_loss'], label='Fine-tune Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# Confusion matrix and classification report
y_true = []
y_pred = []
for images, labels in val_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(tf.argmax(preds, axis=1).numpy())

class_names = ["Cardboard", "Glass", "Metal", "Paper", "Miscellaneous Trash", "Plastic", "Textile Trash", "Vegetation", "Other"]
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# Classification Report:
#                       precision    recall  f1-score   support
#
#           Cardboard       0.00      0.00      0.00        74
#               Glass       0.00      0.00      0.00        84
#               Metal       0.00      0.00      0.00        78
#               Paper       0.00      0.00      0.00       173
# Miscellaneous Trash       0.00      0.00      0.00        92
#             Plastic       0.00      0.00      0.00       119
#       Textile Trash       0.19      1.00      0.32       179
#          Vegetation       0.00      0.00      0.00        75
#               Other       0.00      0.00      0.00        76
#
#            accuracy                           0.19       950
#           macro avg       0.02      0.11      0.04       950
#        weighted avg       0.04      0.19      0.06       950
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ## Part 3: Waste Description Classification
#
# In this section, you will build a text classification model to categorize waste based on descriptions.

# %% [markdown]
# ### 3.1 Preprocess Text Data

# %%
# TODO: Implement text preprocessing
# - Apply the text preprocessing pipeline created earlier

# Load your waste descriptions CSV
waste_df = pd.read_csv("./Waste Descriptions.csv")

# Quick look
print(waste_df.head())

# Define a simple text cleaning function
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)  # Remove punctuation and special chars
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

# Apply cleaning
waste_df['description_clean'] = waste_df['description'].apply(clean_text)

# Print a sample
print(waste_df[['description', 'description_clean']].sample(3))

# Split into train/val/test (stratified)
train_df, temp_df = train_test_split(
    waste_df, test_size=0.2, stratify=waste_df['category'], random_state=42
)
val_df, test_df = train_test_split(
    temp_df, test_size=0.5, stratify=temp_df['category'], random_state=42
)

print("Train:", train_df.shape)
print("Val:  ", val_df.shape)
print("Test: ", test_df.shape)
# Out:
#                                          description       category  \
# 0                           soiled silver tablecloth  Textile Trash
# 1                        folded glass bottle leaking          Glass
# 2  large Supermarket vegetable waste with food re...  Food Organics
# 3                         intact floral carpet piece  Textile Trash
# 4                  empty fun-sized purple apple core  Food Organics
#
#                                 disposal_instruction  \
# 0  Look for textile recycling programs in your area.
# 1     Remove caps, lids, and corks before recycling.
# 2   If no compost available, place in general waste.
# 3  Look for textile recycling programs in your area.
# 4           Keep separate from recyclable materials.
#
#                                     common_confusion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Meat and dairy products may be restricted in s...
#
#                                 material_composition
# 0  Fabric made from natural or synthetic fibers, ...
# 1  Silica-based material, may contain additives f...
# 2  Biodegradable matter derived from plant or ani...
# 3  Fabric made from natural or synthetic fibers, ...
# 4  Biodegradable matter derived from plant or ani...
#                                             description  \
# 1501                    standard yellow glass jar empty
# 2586                              patterned banana peel
# 2653  ripped compact floral composite Homemade baby ...
#
#                                       description_clean
# 1501                    standard yellow glass jar empty
# 2586                              patterned banana peel
# 2653  ripped compact floral composite homemade baby ...
# Train: (4000, 6)
# Val:   (500, 6)
# Test:  (500, 6)

# %% [markdown]
# ### 3.2 Implement Text Classification Model

# %%
# TODO: Choose and implement a text classification model
# Option A: Traditional ML model (Naive Bayes, Random Forest, etc.)
# Option B: Fine-tune a transformer-based model (BERT, DistilBERT, etc.)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix

# Vectorize the text descriptions
vectorizer = TfidfVectorizer(
    max_features=5000, 
    ngram_range=(1, 2), 
    stop_words='english'
)
X_train = vectorizer.fit_transform(train_df['description_clean'])
X_val   = vectorizer.transform(val_df['description_clean'])
X_test  = vectorizer.transform(test_df['description_clean'])

# Encode the category labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_df['category'])
y_val   = label_encoder.transform(val_df['category'])
y_test  = label_encoder.transform(test_df['category'])

# Train a Naive Bayes classifier
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)

# Evaluate the model on the test set
y_pred = nb_model.predict(X_test)
print("Classification report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# Function to classify new text descriptions
def classify_text(text):
    X = vectorizer.transform([text])
    class_idx = nb_model.predict(X)[0]
    return label_encoder.inverse_transform([class_idx])[0]

# Example usage
print(classify_text("small plastic soda bottle"))
# Out:
# Classification report:
#                       precision    recall  f1-score   support
#
#           Cardboard       1.00      1.00      1.00        59
#       Food Organics       1.00      1.00      1.00        52
#               Glass       1.00      1.00      1.00        55
#               Metal       1.00      1.00      1.00        50
# Miscellaneous Trash       1.00      0.97      0.98        58
#               Paper       1.00      1.00      1.00        51
#             Plastic       0.98      1.00      0.99        57
#       Textile Trash       0.98      1.00      0.99        58
#          Vegetation       1.00      1.00      1.00        60
#
#            accuracy                           1.00       500
#           macro avg       1.00      1.00      1.00       500
#        weighted avg       1.00      1.00      1.00       500
#
# Plastic

# %% [markdown]
# ### 3.3 Train and Evaluate the Model

# %%
# TODO: Train the text classification model
# - Use appropriate training parameters
# - Monitor training progress
val_pred = nb_model.predict(X_val)
from sklearn.metrics import accuracy_score
val_accuracy = accuracy_score(y_val, val_pred)
print(f"Validation accuracy: {val_accuracy:.3f}")

# Train the model
nb_model.fit(X_train, y_train)

# Evaluate on validation set
val_pred = nb_model.predict(X_val)
val_accuracy = accuracy_score(y_val, val_pred)
print(f"Validation accuracy: {val_accuracy:.3f}")

# Evaluate on test set
y_pred = nb_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test accuracy: {test_accuracy:.3f}")

print("Classification report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# Validation accuracy: 0.996
# Validation accuracy: 0.996
# Test accuracy: 0.996
# Classification report:
#                       precision    recall  f1-score   support
#
#           Cardboard       1.00      1.00      1.00        59
#       Food Organics       1.00      1.00      1.00        52
#               Glass       1.00      1.00      1.00        55
#               Metal       1.00      1.00      1.00        50
# Miscellaneous Trash       1.00      0.97      0.98        58
#               Paper       1.00      1.00      1.00        51
#             Plastic       0.98      1.00      0.99        57
#       Textile Trash       0.98      1.00      0.99        58
#          Vegetation       1.00      1.00      1.00        60
#
#            accuracy                           1.00       500
#           macro avg       1.00      1.00      1.00       500
#        weighted avg       1.00      1.00      1.00       500

# %%
# Plot training progress
y_pred = nb_model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=label_encoder.classes_, 
            yticklabels=label_encoder.classes_)
plt.title("Test Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()


train_acc = accuracy_score(y_train, nb_model.predict(X_train))
val_acc = accuracy_score(y_val, nb_model.predict(X_val))
test_acc = accuracy_score(y_test, nb_model.predict(X_test))

plt.bar(['Train', 'Validation', 'Test'], [train_acc, val_acc, test_acc])
plt.ylabel("Accuracy")
plt.ylim(0, 1)
plt.title("Naive Bayes Classification Accuracy")
plt.show()

# %%
# TODO: Evaluate model performance
# - Calculate accuracy on test set
# - Generate confusion matrix
# - Analyze error patterns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Get predictions
y_pred = nb_model.predict(X_test)

# Calculate accuracy
test_accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {test_accuracy:.3f}")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.title("Test Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# Analyze top 5 most confused class pairs
print("\nTop 5 most confused class pairs:")
cm_no_diag = cm.copy()
np.fill_diagonal(cm_no_diag, 0)
for _ in range(5):
    i, j = np.unravel_index(np.argmax(cm_no_diag), cm_no_diag.shape)
    if cm_no_diag[i, j] == 0:
        break
    print(f"{label_encoder.classes_[i]} vs {label_encoder.classes_[j]}: {cm_no_diag[i, j]} times")
    cm_no_diag[i, j] = 0
# Out:
# Test Accuracy: 0.996
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#           Cardboard       1.00      1.00      1.00        59
#       Food Organics       1.00      1.00      1.00        52
#               Glass       1.00      1.00      1.00        55
#               Metal       1.00      1.00      1.00        50
# Miscellaneous Trash       1.00      0.97      0.98        58
#               Paper       1.00      1.00      1.00        51
#             Plastic       0.98      1.00      0.99        57
#       Textile Trash       0.98      1.00      0.99        58
#          Vegetation       1.00      1.00      1.00        60
#
#            accuracy                           1.00       500
#           macro avg       1.00      1.00      1.00       500
#        weighted avg       1.00      1.00      1.00       500
# Top 5 most confused class pairs:
# Miscellaneous Trash vs Plastic: 1 times
# Miscellaneous Trash vs Textile Trash: 1 times

# %% [markdown]
# ### 3.4 Create Classification Function

# %%
# TODO: Create a function that takes a text description and returns the predicted waste category
def classify_waste_description(description):
    """
    Classifies a waste description into an appropriate category.
    
    Args:
        description (str): Text description of waste item
        
    Returns:
        str: Predicted waste category
    """
    # Clean description (match your TFIDF preprocessing, if any)
    import re
    def clean_text(text):
        text = str(text).lower()
        text = re.sub(r'[^a-z0-9\s]', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text

    cleaned = clean_text(description)
    # Vectorize using the same vectorizer as training
    X = vectorizer.transform([cleaned])
    class_idx = nb_model.predict(X)[0]
    category = label_encoder.inverse_transform([class_idx])[0]
    return category

# Example usage:
desc = "empty glass bottle with broken top"
print("Predicted category:", classify_waste_description(desc))
# Out:
# Predicted category: Glass

# %% [markdown]
# ## Part 4: Recycling Instruction Generation with RAG
#
# In this section, you will implement a Retrieval-Augmented Generation (RAG) system to generate recycling instructions.

# %% [markdown]
# ### 4.1 Preprocess Documents for Retrieval

# %%
# TODO: Prepare documents for retrieval
# - Process policy documents and disposal instructions
# - Create embeddings for efficient retrieval
import pandas as pd
from sentence_transformers import SentenceTransformer

# Load JSON and CSV properly
policy_docs = pd.read_json("waste policy documents.json")    # Use read_json for JSON!
desc_docs   = pd.read_csv("Waste Descriptions.csv")          # CSV as normal

# Select text and metadata columns (update column names as needed)
policy_texts = policy_docs['document_text'].fillna("").tolist()
policy_meta  = policy_docs.to_dict('records')

desc_texts = desc_docs['disposal_instruction'].fillna("").tolist()
desc_meta  = desc_docs.to_dict('records')

# Combine into a single corpus (for a unified search experience)
all_texts = policy_texts + desc_texts
all_meta  = policy_meta + desc_meta

# Load sentence transformer model
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

print("Generating embeddings...")
doc_embeddings = embedding_model.encode(all_texts, show_progress_bar=True)
print("Embeddings shape:", doc_embeddings.shape)

# Check a sample embedding & associated metadata
print("\nSample doc:", all_texts[0][:100], "...")
print("Sample embedding:", doc_embeddings[0][:5])
print("Sample metadata:", all_meta[0])
# Out:
# Generating embeddings...
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# Embeddings shape: (5014, 384)
#
# Sample doc: TEXTILE RECYCLING GUIDELINES
#
# Acceptable Items:
# - Clean clothing (all conditions)
# - Towels, sheets,  ...
# Sample embedding: [-0.06967729  0.05245302  0.00432378 -0.01666911  0.05976699]
# Sample metadata: {'policy_id': 1, 'policy_type': 'Textile Trash Recycling Guidelines', 'categories_covered': ['Textile Trash'], 'effective_date': '2023-11-04', 'document_text': 'TEXTILE RECYCLING GUIDELINES\n\nAcceptable Items:\n- Clean clothing (all conditions)\n- Towels, sheets, and linens\n- Fabric scraps\n- Curtains and cloth napkins\n- Handbags and backpacks made of fabric\n- Soft toys and stuffed animals\n\nNon-Acceptable Items:\n- Wet or moldy textiles\n- Heavily soiled items\n- Carpets and rugs\n- Footwear\n- Items with significant non-textile parts\n\nCollection Method:\nPlace items in dedicated textile recycling bins or donate to local thrift stores.\n\nPreparation Instructions:\n- Ensure all items are clean and dry\n- Remove non-textile components when possible\n- Bag similar items together\n\nBenefits:\nTextile recycling conserves resources and reduces landfill waste.', 'jurisdiction': 'Metro City'}

# %% [markdown]
# ### 4.2 Implement RAG-based System

# %%
# TODO: Select a pre-trained language model and implement RAG
# - Choose an appropriate language model
# - Create a retrieval mechanism
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM
from sklearn.metrics.pairwise import cosine_similarity


retrieval_model = SentenceTransformer('all-MiniLM-L6-v2')
gen_model_name  = "gpt2"  # Or try 'distilgpt2', 'gpt2-medium', etc.
tokenizer = AutoTokenizer.from_pretrained(gen_model_name)
generator = AutoModelForCausalLM.from_pretrained(gen_model_name)

# Create a retrieval function
def retrieve_relevant_docs(query, doc_embeddings, documents, metadata, top_k=3):
    # Embed query
    query_emb = retrieval_model.encode([query])
    # Compute similarities
    similarities = cosine_similarity(query_emb, doc_embeddings)[0]
    # Rank and select top_k
    top_idx = similarities.argsort()[-top_k:][::-1]
    results = [(documents[i], metadata[i], similarities[i]) for i in top_idx]
    return results

query = "What do I do with soiled pizza boxes?"
top_docs = retrieve_relevant_docs(query, doc_embeddings, all_texts, all_meta, top_k=3)

print("Top retrieved docs:")
for content, meta, score in top_docs:
    print(f"Score: {score:.3f}\nText: {content[:100]}...\nMeta: {meta}\n")
# Out:
# Top retrieved docs:
# Score: 0.525
# Text: CARDBOARD RECYCLING GUIDELINES
#
# Acceptable Items:
# - Corrugated cardboard boxes
# - Paperboard (cereal ...
# Meta: {'policy_id': 6, 'policy_type': 'Cardboard Recycling Guidelines', 'categories_covered': ['Cardboard'], 'effective_date': '2023-11-24', 'document_text': 'CARDBOARD RECYCLING GUIDELINES\n\nAcceptable Items:\n- Corrugated cardboard boxes\n- Paperboard (cereal boxes, etc.)\n- Cardboard packaging\n- Cardboard tubes\n- Clean pizza boxes\n\nNon-Acceptable Items:\n- Waxed cardboard\n- Cardboard with food residue\n- Cardboard with plastic linings\n- Foam inserts\n- Packing peanuts\n\nCollection Method:\nFlatten and place in recycling bins or take to cardboard recycling centers.\n\nPreparation Instructions:\n- Remove all non-cardboard packaging\n- Flatten boxes to save space\n- Keep dry and clean\n\nBenefits:\nRecycling cardboard saves trees and reduces landfill volume significantly.', 'jurisdiction': 'Metro City'}
#
# Score: 0.522
# Text: Flatten boxes before placing in cardboard recycling....
# Meta: {'description': 'used green file box', 'category': 'Cardboard', 'disposal_instruction': 'Flatten boxes before placing in cardboard recycling.', 'common_confusion': 'Pizza boxes with food stains should go in organic waste or general trash, not recycling.', 'material_composition': 'Thick paper pulp formed into corrugated or solid sheets.'}
#
# Score: 0.522
# Text: Flatten boxes before placing in cardboard recycling....
# Meta: {'description': 'stained compact brown food packaging', 'category': 'Cardboard', 'disposal_instruction': 'Flatten boxes before placing in cardboard recycling.', 'common_confusion': nan, 'material_composition': 'Thick paper pulp formed into corrugated or solid sheets.'}

# %% [markdown]
# ### 4.3 Adjust and Evaluate the System

# %%
# TODO: Train the RAG-based system
# - Adjust sampling methods/parameters
import numpy as np
from types import SimpleNamespace as Namespace
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForCausalLM
import pandas as pd

policy_texts = policy_docs['document_text'].fillna("").tolist()
desc_texts   = desc_docs['disposal_instruction'].fillna("").tolist()
all_texts    = policy_texts + desc_texts

# Build Retriever 
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
print("Encoding documents...")
document_embeddings = embedding_model.encode(all_texts, show_progress_bar=True)

# Build Generator 
tokenizer = AutoTokenizer.from_pretrained('gpt2')  
model = AutoModelForCausalLM.from_pretrained('gpt2')
generator = Namespace(tokenizer=tokenizer, model=model)

# RAG function
def generate_rag_instruction(
    query, policy_embeddings, policy_texts, retriever, generator,
    top_k=2, temperature=1.0, max_new_tokens=64
):
    # Retrieve relevant snippets
    query_emb = retriever.encode([query])
    similarities = np.inner(query_emb, policy_embeddings)[0]
    top_indices = similarities.argsort()[::-1][:top_k]
    retrieved_snippets = [policy_texts[i] for i in top_indices]
    context = "\n".join(retrieved_snippets)
    prompt = f"Instruction context:\n{context}\n\nQuestion: {query}\nInstruction:"
    
    # Tokenize prompt with truncation (to model max length)
    inputs = generator.tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=generator.tokenizer.model_max_length  # use model's max input length
    )
    
    # Generate response, set how much to generate
    outputs = generator.model.generate(
        input_ids=inputs.input_ids,
        attention_mask=inputs.attention_mask,
        do_sample=True,
        temperature=temperature,
        max_new_tokens=max_new_tokens,  # controls output length
        top_p=0.95,
        top_k=50,
        num_return_sequences=1
    )
    response = generator.tokenizer.decode(outputs[0], skip_special_tokens=True)
    instruction = response.split("Instruction:")[-1].strip()
    return instruction


# Example usage
sample_questions = [
    "How should I dispose of a broken glass bottle?",
    "What is the correct bin for oily pizza boxes?",
    "Can textiles go into regular recycling?",
]

for question in sample_questions:
    instruction = generate_rag_instruction(
        query=question,
        policy_embeddings=document_embeddings,
        policy_texts=all_texts,
        retriever=embedding_model,
        generator=generator,
        top_k=2,
        temperature=0.8,
        max_new_tokens=64   
    )
    print(f"Q: {question}")
    print(f"Generated Instruction: {instruction}")
    print("-" * 50)
# Out:
# Encoding documents...
# Batches:   0%|          | 0/157 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Q: How should I dispose of a broken glass bottle?
# Generated Instruction: Cleaning glass should be put into a clean bucket.
#
# Cleaning glass should be
# --------------------------------------------------
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Q: What is the correct bin for oily pizza boxes?
# Generated Instruction: Place in recycling bins or take to cardboard recycling centers.
#
# Benefits:
#
# Place in paper recycling bin for easy recycling and recycling of paper.
#
# Place in recycling bin for non-paperless recycling.
#
# Place in recycling bin for recycling of plastic or other materials.
#
# Place in
# --------------------------------------------------
# Q: Can textiles go into regular recycling?
# Generated Instruction: Textile recycling can be done using a recyclable material that will not break the law.
#
# Source:
#
# http://www.museum.com/publications/textile-recycling/detail.asp?id=22
#
# http://www.museum.com/public
# --------------------------------------------------

# %%
# TODO: Evaluate the quality of generated instructions
# - Test with various waste categories
# - Assess relevance and accuracy

def evaluate_rag_system(test_queries, policy_embeddings, policy_texts, retriever, generator, print_output=True):
    results = []
    for query in test_queries:
        instruction = generate_rag_instruction(
            query,
            policy_embeddings=policy_embeddings,
            policy_texts=policy_texts,
            retriever=retriever,
            generator=generator,
            top_k=2,
            temperature=0.8        )
        if print_output:
            print(f"Query: {query}")
            print(f"Generated Instruction: {instruction}")
            print("-" * 50)
        results.append({'query': query, 'generated_instruction': instruction})
    return results

# Example queries to test a range of waste categories
test_queries = [
    "Where do I throw away plastic bags?",
    "How should I dispose of old clothes?",
    "Can glass jars go in the recycling bin?",
    "What to do with leftover food waste?",
    "How do I get rid of broken electronics?",
    "Can greasy pizza boxes be recycled?",
]

# Run the evaluation (replace variables with your objects)
eval_results = evaluate_rag_system(
    test_queries=test_queries,
    policy_embeddings=document_embeddings,
    policy_texts=all_texts,
    retriever=embedding_model,
    generator=Namespace(tokenizer=tokenizer, model=model),  # or your own wrapper class
    print_output=True
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Query: Where do I throw away plastic bags?
# Generated Instruction: All bags are in a landfill.
#
# All bags are in a landfill.
#
# Question: Can I recycle my plastic bag?
#
# Instruction
# --------------------------------------------------
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Query: How should I dispose of old clothes?
# Generated Instruction: This option should be removed from the store shelves by the store manager or through the recycling department.
#
# Other options:
#
# If you use a local recyclable store, do not dispose of old clothes from there.
#
# You can store old clothing for recycling in an airtight container that is stored
# --------------------------------------------------
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Query: Can glass jars go in the recycling bin?
# Generated Instruction: Locate the bin by using a screwdriver or a small, non-stick or nail-sized plastic container, such as a plastic water bottle or plastic bottles.
#
# Replace the container with a piece of paper and/or paperclip, and place the jar in the recycle bin.
#
# Non
# --------------------------------------------------
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Query: What to do with leftover food waste?
# Generated Instruction: Where compost is not available, place in general waste.
# --------------------------------------------------
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Query: How do I get rid of broken electronics?
# Generated Instruction: Electronics should be
# --------------------------------------------------
# Query: Can greasy pizza boxes be recycled?
# Generated Instruction: - Refinish any cardboard or plastic container.
#
# Non-Acceptable Items:
#
# - Packing peanuts
#
# - Pet food
#
# - Water
#
# Collection Method:
#
# Leave empty packaging on premises and dump them on a compostable landfill.
#
# Preparation Instructions:
# --------------------------------------------------

# %% [markdown]
# ### 4.4 Create Instruction Generation Function

# %%
# TODO: Create a function that takes a waste category and generates recycling instructions
def generate_recycling_instructions(waste_category):
    """
    Generates detailed recycling instructions for a given waste category.

    Args:
        waste_category (str): Waste category

    Returns:
        str: Detailed recycling instructions
        list: Relevant policy document texts
    """
    # Find recycling instructions from the descriptions dataset
    instructions = desc_docs[desc_docs['category'].str.lower() == waste_category.lower()]['disposal_instruction'].dropna().tolist()
    if not instructions:
        instructions = ["No specific instructions found for this category. Please consult your local recycling guidelines."]
    
    # Find relevant policy docs (if there's a category field; else return all docs)
    if 'category' in policy_docs.columns:
        relevant_policies = policy_docs[policy_docs['category'].str.lower() == waste_category.lower()]['document_text'].dropna().tolist()
    else:
        relevant_policies = policy_docs['document_text'].dropna().tolist()
    
    # Compose a friendly, detailed output
    detailed_instructions = f"**Recycling instructions for '{waste_category}':**\n"
    for i, instr in enumerate(instructions, 1):
        detailed_instructions += f"{i}. {instr}\n"
    
    if relevant_policies:
        detailed_instructions += "\nRelevant policy documents:\n"
        for i, doc in enumerate(relevant_policies[:3], 1):  # show up to 3
            detailed_instructions += f"- {doc[:120]}{'...' if len(doc) > 120 else ''}\n"  # Truncate for readability
    else:
        detailed_instructions += "\nNo specific policy documents found."
    
    return detailed_instructions, relevant_policies

# Example usage:
category = "Plastic"
instructions, policy_docs = generate_recycling_instructions(category)
print(instructions)
# Out:
# **Recycling instructions for 'Plastic':**
# 1. Remove labels if possible.
# 2. Plastic bags can be returned to supermarket collection points.
# 3. Rinse container before recycling.
# 4. If unmarked or non-recyclable plastic, place in general waste.
# 5. Check recycling number on bottom and sort accordingly.
# 6. Remove labels if possible.
# 7. Rinse container before recycling.
# 8. If unmarked or non-recyclable plastic, place in general waste.
# 9. Plastic bags can be returned to supermarket collection points.
# 10. Rinse container before recycling.
# 11. If unmarked or non-recyclable plastic, place in general waste.
# 12. Plastic bags can be returned to supermarket collection points.
# 13. If unmarked or non-recyclable plastic, place in general waste.
# 14. Plastic bags can be returned to supermarket collection points.
# 15. Remove labels if possible.
# 16. Rinse container before recycling.
# 17. Plastic bags can be returned to supermarket collection points.
# 18. Plastic bags can be returned to supermarket collection points.
# 19. Check recycling number on bottom and sort accordingly.
# 20. If unmarked or non-recyclable plastic, place in general waste.
# 21. Plastic bags can be returned to supermarket collection points.
# 22. Check recycling number on bottom and sort accordingly.
# 23. Plastic bags can be returned to supermarket collection points.
# 24. Plastic bags can be returned to supermarket collection points.
# 25. Rinse container before recycling.
# 26. If unmarked or non-recyclable plastic, place in general waste.
# 27. Remove labels if possible.
# 28. Remove labels if possible.
# 29. Remove labels if possible.
# 30. Check recycling number on bottom and sort accordingly.
# 31. If unmarked or non-recyclable plastic, place in general waste.
# 32. Rinse container before recycling.
# 33. Plastic bags can be returned to supermarket collection points.
# 34. Remove labels if possible.
# 35. Remove labels if possible.
# 36. Plastic bags can be returned to supermarket collection points.
# 37. Check recycling number on bottom and sort accordingly.
# 38. Rinse container before recycling.
# 39. Remove labels if possible.
# 40. Rinse container before recycling.
# 41. Rinse container before recycling.
# 42. Remove labels if possible.
# 43. Rinse container before recycling.
# 44. If unmarked or non-recyclable plastic, place in general waste.
# 45. If unmarked or non-recyclable plastic, place in general waste.
# 46. Check recycling number on bottom and sort accordingly.
# 47. Rinse container before recycling.
# 48. Remove labels if possible.
# 49. Rinse container before recycling.
# 50. Plastic bags can be returned to supermarket collection points.
# 51. Plastic bags can be returned to supermarket collection points.
# 52. Rinse container before recycling.
# 53. Plastic bags can be returned to supermarket collection points.
# 54. Remove labels if possible.
# 55. Check recycling number on bottom and sort accordingly.
# 56. Remove labels if possible.
# 57. Check recycling number on bottom and sort accordingly.
# 58. Plastic bags can be returned to supermarket collection points.
# 59. Check recycling number on bottom and sort accordingly.
# 60. Rinse container before recycling.
# 61. Check recycling number on bottom and sort accordingly.
# 62. If unmarked or non-recyclable plastic, place in general waste.
# 63. Rinse container before recycling.
# 64. If unmarked or non-recyclable plastic, place in general waste.
# 65. If unmarked or non-recyclable plastic, place in general waste.
# 66. Rinse container before recycling.
# 67. Rinse container before recycling.
# 68. Remove labels if possible.
# 69. Plastic bags can be returned to supermarket collection points.
# 70. Check recycling number on bottom and sort accordingly.
# 71. Plastic bags can be returned to supermarket collection points.
# 72. Remove labels if possible.
# 73. Rinse container before recycling.
# 74. Remove labels if possible.
# 75. Remove labels if possible.
# 76. If unmarked or non-recyclable plastic, place in general waste.
# 77. Rinse container before recycling.
# 78. Rinse container before recycling.
# 79. If unmarked or non-recyclable plastic, place in general waste.
# 80. If unmarked or non-recyclable plastic, place in general waste.
# 81. Remove labels if possible.
# 82. If unmarked or non-recyclable plastic, place in general waste.
# 83. Remove labels if possible.
# 84. Remove labels if possible.
# 85. Check recycling number on bottom and sort accordingly.
# 86. Plastic bags can be returned to supermarket collection points.
# 87. Plastic bags can be returned to supermarket collection points.
# 88. If unmarked or non-recyclable plastic, place in general waste.
# 89. Remove labels if possible.
# 90. If unmarked or non-recyclable plastic, place in general waste.
# 91. Remove labels if possible.
# 92. If unmarked or non-recyclable plastic, place in general waste.
# 93. Remove labels if possible.
# 94. Plastic bags can be returned to supermarket collection points.
# 95. Plastic bags can be returned to supermarket collection points.
# 96. Plastic bags can be returned to supermarket collection points.
# 97. Plastic bags can be returned to supermarket collection points.
# 98. Rinse container before recycling.
# 99. Remove labels if possible.
# 100. Rinse container before recycling.
# 101. Check recycling number on bottom and sort accordingly.
# 102. Check recycling number on bottom and sort accordingly.
# 103. Rinse container before recycling.
# 104. Rinse container before recycling.
# 105. Plastic bags can be returned to supermarket collection points.
# 106. Rinse container before recycling.
# 107. Remove labels if possible.
# 108. Check recycling number on bottom and sort accordingly.
# 109. Check recycling number on bottom and sort accordingly.
# 110. Check recycling number on bottom and sort accordingly.
# 111. Remove labels if possible.
# 112. Remove labels if possible.
# 113. Plastic bags can be returned to supermarket collection points.
# 114. Remove labels if possible.
# 115. Remove labels if possible.
# 116. Plastic bags can be returned to supermarket collection points.
# 117. If unmarked or non-recyclable plastic, place in general waste.
# 118. Check recycling number on bottom and sort accordingly.
# 119. Remove labels if possible.
# 120. Plastic bags can be returned to supermarket collection points.
# 121. If unmarked or non-recyclable plastic, place in general waste.
# 122. Plastic bags can be returned to supermarket collection points.
# 123. If unmarked or non-recyclable plastic, place in general waste.
# 124. Remove labels if possible.
# 125. Check recycling number on bottom and sort accordingly.
# 126. Rinse container before recycling.
# 127. Rinse container before recycling.
# 128. Rinse container before recycling.
# 129. If unmarked or non-recyclable plastic, place in general waste.
# 130. Check recycling number on bottom and sort accordingly.
# 131. Check recycling number on bottom and sort accordingly.
# 132. Check recycling number on bottom and sort accordingly.
# 133. If unmarked or non-recyclable plastic, place in general waste.
# 134. Plastic bags can be returned to supermarket collection points.
# 135. Check recycling number on bottom and sort accordingly.
# 136. Check recycling number on bottom and sort accordingly.
# 137. Rinse container before recycling.
# 138. Check recycling number on bottom and sort accordingly.
# 139. If unmarked or non-recyclable plastic, place in general waste.
# 140. Remove labels if possible.
# 141. Check recycling number on bottom and sort accordingly.
# 142. Remove labels if possible.
# 143. Check recycling number on bottom and sort accordingly.
# 144. If unmarked or non-recyclable plastic, place in general waste.
# 145. Rinse container before recycling.
# 146. If unmarked or non-recyclable plastic, place in general waste.
# 147. If unmarked or non-recyclable plastic, place in general waste.
# 148. Rinse container before recycling.
# 149. Rinse container before recycling.
# 150. Plastic bags can be returned to supermarket collection points.
# 151. Remove labels if possible.
# 152. Rinse container before recycling.
# 153. Plastic bags can be returned to supermarket collection points.
# 154. Plastic bags can be returned to supermarket collection points.
# 155. Rinse container before recycling.
# 156. Rinse container before recycling.
# 157. Plastic bags can be returned to supermarket collection points.
# 158. Check recycling number on bottom and sort accordingly.
# 159. Remove labels if possible.
# 160. If unmarked or non-recyclable plastic, place in general waste.
# 161. Rinse container before recycling.
# 162. Rinse container before recycling.
# 163. Check recycling number on bottom and sort accordingly.
# 164. Check recycling number on bottom and sort accordingly.
# 165. Rinse container before recycling.
# 166. Rinse container before recycling.
# 167. Rinse container before recycling.
# 168. Plastic bags can be returned to supermarket collection points.
# 169. Check recycling number on bottom and sort accordingly.
# 170. Remove labels if possible.
# 171. Plastic bags can be returned to supermarket collection points.
# 172. Plastic bags can be returned to supermarket collection points.
# 173. Rinse container before recycling.
# 174. Plastic bags can be returned to supermarket collection points.
# 175. Check recycling number on bottom and sort accordingly.
# 176. If unmarked or non-recyclable plastic, place in general waste.
# 177. Rinse container before recycling.
# 178. If unmarked or non-recyclable plastic, place in general waste.
# 179. Plastic bags can be returned to supermarket collection points.
# 180. Plastic bags can be returned to supermarket collection points.
# 181. Check recycling number on bottom and sort accordingly.
# 182. Remove labels if possible.
# 183. Remove labels if possible.
# 184. Plastic bags can be returned to supermarket collection points.
# 185. Remove labels if possible.
# 186. Plastic bags can be returned to supermarket collection points.
# 187. Plastic bags can be returned to supermarket collection points.
# 188. Plastic bags can be returned to supermarket collection points.
# 189. Rinse container before recycling.
# 190. Plastic bags can be returned to supermarket collection points.
# 191. Rinse container before recycling.
# 192. If unmarked or non-recyclable plastic, place in general waste.
# 193. Rinse container before recycling.
# 194. Check recycling number on bottom and sort accordingly.
# 195. Rinse container before recycling.
# 196. Check recycling number on bottom and sort accordingly.
# 197. Plastic bags can be returned to supermarket collection points.
# 198. Check recycling number on bottom and sort accordingly.
# 199. Remove labels if possible.
# 200. Check recycling number on bottom and sort accordingly.
# 201. Check recycling number on bottom and sort accordingly.
# 202. Plastic bags can be returned to supermarket collection points.
# 203. Check recycling number on bottom and sort accordingly.
# 204. Rinse container before recycling.
# 205. Rinse container before recycling.
# 206. If unmarked or non-recyclable plastic, place in general waste.
# 207. Plastic bags can be returned to supermarket collection points.
# 208. If unmarked or non-recyclable plastic, place in general waste.
# 209. Remove labels if possible.
# 210. Check recycling number on bottom and sort accordingly.
# 211. Rinse container before recycling.
# 212. If unmarked or non-recyclable plastic, place in general waste.
# 213. Plastic bags can be returned to supermarket collection points.
# 214. Remove labels if possible.
# 215. If unmarked or non-recyclable plastic, place in general waste.
# 216. Rinse container before recycling.
# 217. Check recycling number on bottom and sort accordingly.
# 218. Plastic bags can be returned to supermarket collection points.
# 219. Plastic bags can be returned to supermarket collection points.
# 220. Plastic bags can be returned to supermarket collection points.
# 221. Remove labels if possible.
# 222. Check recycling number on bottom and sort accordingly.
# 223. If unmarked or non-recyclable plastic, place in general waste.
# 224. Check recycling number on bottom and sort accordingly.
# 225. Plastic bags can be returned to supermarket collection points.
# 226. Plastic bags can be returned to supermarket collection points.
# 227. Rinse container before recycling.
# 228. Plastic bags can be returned to supermarket collection points.
# 229. Remove labels if possible.
# 230. Plastic bags can be returned to supermarket collection points.
# 231. Remove labels if possible.
# 232. Rinse container before recycling.
# 233. Check recycling number on bottom and sort accordingly.
# 234. Rinse container before recycling.
# 235. Check recycling number on bottom and sort accordingly.
# 236. Rinse container before recycling.
# 237. Check recycling number on bottom and sort accordingly.
# 238. Plastic bags can be returned to supermarket collection points.
# 239. Remove labels if possible.
# 240. Check recycling number on bottom and sort accordingly.
# 241. If unmarked or non-recyclable plastic, place in general waste.
# 242. Plastic bags can be returned to supermarket collection points.
# 243. Remove labels if possible.
# 244. If unmarked or non-recyclable plastic, place in general waste.
# 245. Plastic bags can be returned to supermarket collection points.
# 246. Remove labels if possible.
# 247. If unmarked or non-recyclable plastic, place in general waste.
# 248. Check recycling number on bottom and sort accordingly.
# 249. Remove labels if possible.
# 250. Remove labels if possible.
# 251. If unmarked or non-recyclable plastic, place in general waste.
# 252. If unmarked or non-recyclable plastic, place in general waste.
# 253. Plastic bags can be returned to supermarket collection points.
# 254. Rinse container before recycling.
# 255. Check recycling number on bottom and sort accordingly.
# 256. If unmarked or non-recyclable plastic, place in general waste.
# 257. Rinse container before recycling.
# 258. Remove labels if possible.
# 259. Rinse container before recycling.
# 260. Remove labels if possible.
# 261. If unmarked or non-recyclable plastic, place in general waste.
# 262. Plastic bags can be returned to supermarket collection points.
# 263. Remove labels if possible.
# 264. Rinse container before recycling.
# 265. Rinse container before recycling.
# 266. If unmarked or non-recyclable plastic, place in general waste.
# 267. Remove labels if possible.
# 268. If unmarked or non-recyclable plastic, place in general waste.
# 269. Remove labels if possible.
# 270. Remove labels if possible.
# 271. Rinse container before recycling.
# 272. Remove labels if possible.
# 273. Remove labels if possible.
# 274. Check recycling number on bottom and sort accordingly.
# 275. Plastic bags can be returned to supermarket collection points.
# 276. Rinse container before recycling.
# 277. Plastic bags can be returned to supermarket collection points.
# 278. Remove labels if possible.
# 279. Remove labels if possible.
# 280. If unmarked or non-recyclable plastic, place in general waste.
# 281. Remove labels if possible.
# 282. Remove labels if possible.
# 283. Rinse container before recycling.
# 284. Plastic bags can be returned to supermarket collection points.
# 285. Rinse container before recycling.
# 286. Rinse container before recycling.
# 287. If unmarked or non-recyclable plastic, place in general waste.
# 288. Plastic bags can be returned to supermarket collection points.
# 289. Check recycling number on bottom and sort accordingly.
# 290. Rinse container before recycling.
# 291. Plastic bags can be returned to supermarket collection points.
# 292. Plastic bags can be returned to supermarket collection points.
# 293. If unmarked or non-recyclable plastic, place in general waste.
# 294. If unmarked or non-recyclable plastic, place in general waste.
# 295. Remove labels if possible.
# 296. Check recycling number on bottom and sort accordingly.
# 297. Check recycling number on bottom and sort accordingly.
# 298. Plastic bags can be returned to supermarket collection points.
# 299. Rinse container before recycling.
# 300. Plastic bags can be returned to supermarket collection points.
# 301. Rinse container before recycling.
# 302. Rinse container before recycling.
# 303. Rinse container before recycling.
# 304. Rinse container before recycling.
# 305. Remove labels if possible.
# 306. Plastic bags can be returned to supermarket collection points.
# 307. Remove labels if possible.
# 308. Check recycling number on bottom and sort accordingly.
# 309. Remove labels if possible.
# 310. If unmarked or non-recyclable plastic, place in general waste.
# 311. Check recycling number on bottom and sort accordingly.
# 312. Rinse container before recycling.
# 313. Rinse container before recycling.
# 314. Remove labels if possible.
# 315. Plastic bags can be returned to supermarket collection points.
# 316. Plastic bags can be returned to supermarket collection points.
# 317. Remove labels if possible.
# 318. Rinse container before recycling.
# 319. Remove labels if possible.
# 320. Check recycling number on bottom and sort accordingly.
# 321. If unmarked or non-recyclable plastic, place in general waste.
# 322. Rinse container before recycling.
# 323. Remove labels if possible.
# 324. Rinse container before recycling.
# 325. Rinse container before recycling.
# 326. Plastic bags can be returned to supermarket collection points.
# 327. Remove labels if possible.
# 328. Plastic bags can be returned to supermarket collection points.
# 329. Plastic bags can be returned to supermarket collection points.
# 330. Plastic bags can be returned to supermarket collection points.
# 331. Plastic bags can be returned to supermarket collection points.
# 332. If unmarked or non-recyclable plastic, place in general waste.
# 333. Check recycling number on bottom and sort accordingly.
# 334. Rinse container before recycling.
# 335. Plastic bags can be returned to supermarket collection points.
# 336. Rinse container before recycling.
# 337. Plastic bags can be returned to supermarket collection points.
# 338. Plastic bags can be returned to supermarket collection points.
# 339. Rinse container before recycling.
# 340. Rinse container before recycling.
# 341. If unmarked or non-recyclable plastic, place in general waste.
# 342. Remove labels if possible.
# 343. Check recycling number on bottom and sort accordingly.
# 344. Rinse container before recycling.
# 345. Plastic bags can be returned to supermarket collection points.
# 346. Plastic bags can be returned to supermarket collection points.
# 347. If unmarked or non-recyclable plastic, place in general waste.
# 348. If unmarked or non-recyclable plastic, place in general waste.
# 349. Remove labels if possible.
# 350. Plastic bags can be returned to supermarket collection points.
# 351. Plastic bags can be returned to supermarket collection points.
# 352. Plastic bags can be returned to supermarket collection points.
# 353. Remove labels if possible.
# 354. Remove labels if possible.
# 355. Plastic bags can be returned to supermarket collection points.
# 356. Rinse container before recycling.
# 357. Remove labels if possible.
# 358. If unmarked or non-recyclable plastic, place in general waste.
# 359. Remove labels if possible.
# 360. If unmarked or non-recyclable plastic, place in general waste.
# 361. Check recycling number on bottom and sort accordingly.
# 362. Remove labels if possible.
# 363. Remove labels if possible.
# 364. Plastic bags can be returned to supermarket collection points.
# 365. Remove labels if possible.
# 366. Remove labels if possible.
# 367. Rinse container before recycling.
# 368. If unmarked or non-recyclable plastic, place in general waste.
# 369. Remove labels if possible.
# 370. Rinse container before recycling.
# 371. Check recycling number on bottom and sort accordingly.
# 372. Check recycling number on bottom and sort accordingly.
# 373. Plastic bags can be returned to supermarket collection points.
# 374. Check recycling number on bottom and sort accordingly.
# 375. Rinse container before recycling.
# 376. Remove labels if possible.
# 377. Check recycling number on bottom and sort accordingly.
# 378. Check recycling number on bottom and sort accordingly.
# 379. Remove labels if possible.
# 380. Remove labels if possible.
# 381. Rinse container before recycling.
# 382. Rinse container before recycling.
# 383. If unmarked or non-recyclable plastic, place in general waste.
# 384. Plastic bags can be returned to supermarket collection points.
# 385. Remove labels if possible.
# 386. Check recycling number on bottom and sort accordingly.
# 387. Rinse container before recycling.
# 388. Check recycling number on bottom and sort accordingly.
# 389. Rinse container before recycling.
# 390. Plastic bags can be returned to supermarket collection points.
# 391. Rinse container before recycling.
# 392. Remove labels if possible.
# 393. Remove labels if possible.
# 394. Remove labels if possible.
# 395. Remove labels if possible.
# 396. Check recycling number on bottom and sort accordingly.
# 397. If unmarked or non-recyclable plastic, place in general waste.
# 398. Check recycling number on bottom and sort accordingly.
# 399. Rinse container before recycling.
# 400. Check recycling number on bottom and sort accordingly.
# 401. Plastic bags can be returned to supermarket collection points.
# 402. Plastic bags can be returned to supermarket collection points.
# 403. Check recycling number on bottom and sort accordingly.
# 404. Rinse container before recycling.
# 405. Rinse container before recycling.
# 406. Remove labels if possible.
# 407. Plastic bags can be returned to supermarket collection points.
# 408. Rinse container before recycling.
# 409. Remove labels if possible.
# 410. Remove labels if possible.
# 411. If unmarked or non-recyclable plastic, place in general waste.
# 412. Rinse container before recycling.
# 413. Plastic bags can be returned to supermarket collection points.
# 414. Remove labels if possible.
# 415. If unmarked or non-recyclable plastic, place in general waste.
# 416. Plastic bags can be returned to supermarket collection points.
# 417. If unmarked or non-recyclable plastic, place in general waste.
# 418. Remove labels if possible.
# 419. Plastic bags can be returned to supermarket collection points.
# 420. If unmarked or non-recyclable plastic, place in general waste.
# 421. If unmarked or non-recyclable plastic, place in general waste.
# 422. Check recycling number on bottom and sort accordingly.
# 423. Remove labels if possible.
# 424. Remove labels if possible.
# 425. If unmarked or non-recyclable plastic, place in general waste.
# 426. Rinse container before recycling.
# 427. Remove labels if possible.
# 428. Check recycling number on bottom and sort accordingly.
# 429. Rinse container before recycling.
# 430. Plastic bags can be returned to supermarket collection points.
# 431. Rinse container before recycling.
# 432. Rinse container before recycling.
# 433. Plastic bags can be returned to supermarket collection points.
# 434. If unmarked or non-recyclable plastic, place in general waste.
# 435. Remove labels if possible.
# 436. If unmarked or non-recyclable plastic, place in general waste.
# 437. Check recycling number on bottom and sort accordingly.
# 438. Check recycling number on bottom and sort accordingly.
# 439. Plastic bags can be returned to supermarket collection points.
# 440. Check recycling number on bottom and sort accordingly.
# 441. Check recycling number on bottom and sort accordingly.
# 442. Plastic bags can be returned to supermarket collection points.
# 443. Remove labels if possible.
# 444. Check recycling number on bottom and sort accordingly.
# 445. Rinse container before recycling.
# 446. Remove labels if possible.
# 447. Check recycling number on bottom and sort accordingly.
# 448. If unmarked or non-recyclable plastic, place in general waste.
# 449. Plastic bags can be returned to supermarket collection points.
# 450. Check recycling number on bottom and sort accordingly.
# 451. Check recycling number on bottom and sort accordingly.
# 452. Rinse container before recycling.
# 453. Remove labels if possible.
# 454. If unmarked or non-recyclable plastic, place in general waste.
# 455. Check recycling number on bottom and sort accordingly.
# 456. If unmarked or non-recyclable plastic, place in general waste.
# 457. Plastic bags can be returned to supermarket collection points.
# 458. If unmarked or non-recyclable plastic, place in general waste.
# 459. Plastic bags can be returned to supermarket collection points.
# 460. Remove labels if possible.
# 461. If unmarked or non-recyclable plastic, place in general waste.
# 462. Check recycling number on bottom and sort accordingly.
# 463. If unmarked or non-recyclable plastic, place in general waste.
# 464. Plastic bags can be returned to supermarket collection points.
# 465. Plastic bags can be returned to supermarket collection points.
# 466. Check recycling number on bottom and sort accordingly.
# 467. If unmarked or non-recyclable plastic, place in general waste.
# 468. Remove labels if possible.
# 469. Remove labels if possible.
# 470. Check recycling number on bottom and sort accordingly.
# 471. Remove labels if possible.
# 472. If unmarked or non-recyclable plastic, place in general waste.
# 473. Remove labels if possible.
# 474. Remove labels if possible.
# 475. Check recycling number on bottom and sort accordingly.
# 476. If unmarked or non-recyclable plastic, place in general waste.
# 477. If unmarked or non-recyclable plastic, place in general waste.
# 478. If unmarked or non-recyclable plastic, place in general waste.
# 479. Check recycling number on bottom and sort accordingly.
# 480. If unmarked or non-recyclable plastic, place in general waste.
# 481. If unmarked or non-recyclable plastic, place in general waste.
# 482. Plastic bags can be returned to supermarket collection points.
# 483. Rinse container before recycling.
# 484. Rinse container before recycling.
# 485. Rinse container before recycling.
# 486. Check recycling number on bottom and sort accordingly.
# 487. If unmarked or non-recyclable plastic, place in general waste.
# 488. Plastic bags can be returned to supermarket collection points.
# 489. Rinse container before recycling.
# 490. Remove labels if possible.
# 491. Rinse container before recycling.
# 492. Remove labels if possible.
# 493. Check recycling number on bottom and sort accordingly.
# 494. Check recycling number on bottom and sort accordingly.
# 495. Remove labels if possible.
# 496. Rinse container before recycling.
# 497. If unmarked or non-recyclable plastic, place in general waste.
# 498. Rinse container before recycling.
# 499. Rinse container before recycling.
# 500. Plastic bags can be returned to supermarket collection points.
# 501. If unmarked or non-recyclable plastic, place in general waste.
# 502. Rinse container before recycling.
# 503. Remove labels if possible.
# 504. If unmarked or non-recyclable plastic, place in general waste.
# 505. Check recycling number on bottom and sort accordingly.
# 506. Rinse container before recycling.
# 507. If unmarked or non-recyclable plastic, place in general waste.
# 508. Plastic bags can be returned to supermarket collection points.
# 509. If unmarked or non-recyclable plastic, place in general waste.
# 510. Rinse container before recycling.
# 511. Check recycling number on bottom and sort accordingly.
# 512. If unmarked or non-recyclable plastic, place in general waste.
# 513. Check recycling number on bottom and sort accordingly.
# 514. If unmarked or non-recyclable plastic, place in general waste.
# 515. Plastic bags can be returned to supermarket collection points.
# 516. Check recycling number on bottom and sort accordingly.
# 517. Check recycling number on bottom and sort accordingly.
# 518. Remove labels if possible.
# 519. If unmarked or non-recyclable plastic, place in general waste.
# 520. Rinse container before recycling.
# 521. Remove labels if possible.
# 522. Plastic bags can be returned to supermarket collection points.
# 523. Rinse container before recycling.
# 524. Rinse container before recycling.
# 525. Remove labels if possible.
# 526. Rinse container before recycling.
# 527. Remove labels if possible.
# 528. Rinse container before recycling.
# 529. Plastic bags can be returned to supermarket collection points.
# 530. Rinse container before recycling.
# 531. Check recycling number on bottom and sort accordingly.
# 532. Check recycling number on bottom and sort accordingly.
# 533. Remove labels if possible.
# 534. Remove labels if possible.
# 535. Remove labels if possible.
# 536. Remove labels if possible.
# 537. Remove labels if possible.
# 538. Check recycling number on bottom and sort accordingly.
# 539. Rinse container before recycling.
# 540. Remove labels if possible.
# 541. If unmarked or non-recyclable plastic, place in general waste.
# 542. Rinse container before recycling.
# 543. If unmarked or non-recyclable plastic, place in general waste.
# 544. Plastic bags can be returned to supermarket collection points.
# 545. If unmarked or non-recyclable plastic, place in general waste.
# 546. Check recycling number on bottom and sort accordingly.
# 547. Rinse container before recycling.
# 548. If unmarked or non-recyclable plastic, place in general waste.
# 549. Check recycling number on bottom and sort accordingly.
# 550. Rinse container before recycling.
# 551. Remove labels if possible.
# 552. Rinse container before recycling.
# 553. If unmarked or non-recyclable plastic, place in general waste.
# 554. Rinse container before recycling.
# 555. Check recycling number on bottom and sort accordingly.
# 556. Check recycling number on bottom and sort accordingly.
# 557. Rinse container before recycling.
# 558. Check recycling number on bottom and sort accordingly.
# 559. If unmarked or non-recyclable plastic, place in general waste.
# 560. Remove labels if possible.
# 561. Plastic bags can be returned to supermarket collection points.
# 562. If unmarked or non-recyclable plastic, place in general waste.
# 563. Plastic bags can be returned to supermarket collection points.
# 564. Plastic bags can be returned to supermarket collection points.
# 565. Check recycling number on bottom and sort accordingly.
# 566. Plastic bags can be returned to supermarket collection points.
# 567. Remove labels if possible.
# 568. Rinse container before recycling.
# 569. Check recycling number on bottom and sort accordingly.
#
# Relevant policy documents:
# - TEXTILE RECYCLING GUIDELINES
#
# Acceptable Items:
# - Clean clothing (all conditions)
# - Towels, sheets, and linens
# - Fabric ...
# - GLASS RECYCLING GUIDELINES
#
# Acceptable Items:
# - Glass bottles (all colors)
# - Glass jars
# - Glass food containers
# - Glass ...
# - FOOD ORGANICS RECYCLING GUIDELINES
#
# Acceptable Items:
# - Fruit and vegetable scraps
# - Meat and fish (including bones)
# - D...

# %% [markdown]
# ## Part 5: Integrated Waste Management Assistant
#
# In this section, you will integrate all three models into a unified waste management assistant.

# %% [markdown]
# ### 5.1 Design Integration Architecture

# %%
# TODO: Design an architecture that integrates all three models
# - Create interfaces between components
# - Handle input/output flow
class EcoSortAssistant:
    def __init__(self, image_model, text_model, label_encoder, rag_generator, tokenizer):
        self.image_model = image_model          # Trained Keras CNN model
        self.text_model = text_model            # Trained HuggingFace BERT model (TF version)
        self.label_encoder = label_encoder      # Fitted LabelEncoder
        self.rag_generator = generate_rag_instruction      # RAG generator function
        self.tokenizer = tokenizer              # HuggingFace tokenizer

    def classify_image(self, image):
        img_input = self.preprocess_image(image)
        preds = self.image_model.predict(img_input)
        class_idx = np.argmax(preds, axis=1)[0]
        category = self.label_encoder.inverse_transform([class_idx])[0]
        return category

    def preprocess_image(self, image):  
        import tensorflow as tf
        IMG_SIZE = (224, 224)
        if isinstance(image, str):
            image = tf.io.read_file(image)
            image = tf.image.decode_jpeg(image, channels=3)
        image = tf.image.resize(image, IMG_SIZE)
        image = tf.cast(image, tf.float32) / 255.0
        image = tf.expand_dims(image, axis=0)
        return image

    def rag_generator(category):
        return "Sample instruction", ["Sample doc"]

    
    def preprocess_and_tokenize(self, text):
        return self.tokenizer([text], truncation=True, padding='max_length', max_length=64, return_tensors="tf")
    
    def classify_text(self, description):
        inputs = self.preprocess_and_tokenize(description)
        preds = self.text_model(**inputs)
        class_idx = np.argmax(preds.logits.numpy(), axis=1)[0]
        category = self.label_encoder.inverse_transform([class_idx])[0]
        return category
    
    def generate_instructions(self, waste_category):
        instructions, docs = self.rag_generator(waste_category)
        return instructions, docs

    def handle_input(self, image=None, description=None):
        if image is not None:
            category = self.classify_image(image)
        elif description is not None:
            category = self.classify_text(description)
        else:
            raise ValueError("Must provide an image or a description.")
        instructions, relevant_docs = self.generate_instructions(category)
        return {
            "predicted_category": category,
            "instructions": instructions,
            "relevant_docs": relevant_docs
        }
ecosort_assistant = EcoSortAssistant(
    image_model=model,              # your trained CNN model variable
    text_model=text_model,          # your trained text/BERT model variable
    label_encoder=label_encoder,    # your label encoder
    rag_generator=generate_rag_instruction,  # your RAG generator function
    tokenizer=tokenizer            # your tokenizer
)

# %% [markdown]
# ### 5.2 Implement Integrated Assistant

# %%
# TODO: Implement the integrated waste management assistant
def waste_management_assistant(input_data, input_type="image"):
    """
    Integrated waste management assistant that processes either images or text descriptions
    and returns waste classification and recycling instructions.
    """
    if input_type == "image":
        img = preprocess_image(input_data)
        preds = model.predict(img)
        category_idx = np.argmax(preds)
        confidence = float(np.max(preds))
        category = label_encoder.inverse_transform([category_idx])[0]

    elif input_type == "text":
        # Tokenize and encode input
        tokens = tokenizer(
            [input_data], 
            truncation=True, 
            padding='max_length', 
            max_length=64, 
            return_tensors="tf"
        )
        outputs = text_model(**tokens)
        logits = outputs.logits
        probs = tf.nn.softmax(logits, axis=1).numpy()[0]
        category_idx = int(np.argmax(probs))
        confidence = float(np.max(probs))
        category = label_encoder.inverse_transform([category_idx])[0]

    else:
        raise ValueError("input_type must be 'image' or 'text'.")

    instructions, relevant_docs = generate_recycling_instructions(category)

    return {
        "waste_category": category,
        "confidence": confidence,
        "instructions": instructions,
        "relevant_docs": relevant_docs
    }

# %% [markdown]
# ### 5.3 Evaluate the Integrated System

# %%
# TODO: Evaluate the integrated system on test cases
# - Test with images from test dataset
# - Test with text descriptions from test dataset
# - Assess overall performance
# Evaluate image classification on the test image dataset
# Ensure ecosort_assistant exists and is initialized as shown above
print("First file path:", test_image_df['filepath'].iloc[0])
print("Does it exist?", os.path.isfile(test_image_df['filepath'].iloc[0]))

# Try a single image to debug
print("Single prediction:", ecosort_assistant.classify_image(test_image_df['filepath'].iloc[0]))

# Now do all images



image_true = test_image_df['category'].tolist()
image_pred = [ecosort_assistant.classify_image(filepath) for filepath in test_image_df['filepath']]

# Performance metrics for image classification
print(f"Total images found: {len(image_true)}")
print("\nImage Classification Report:")
print(classification_report(image_true, image_pred, target_names=ecosort_assistant.label_encoder.classes_))

# Confusion matrix for image classification
cm_img = confusion_matrix(image_true, image_pred, labels=ecosort_assistant.label_encoder.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_img, display_labels=ecosort_assistant.label_encoder.classes_)
plt.figure(figsize=(8,6))
disp.plot(xticks_rotation=45)  # rotate labels for readability
plt.title("Image Classification Confusion Matrix")
plt.show()

# Evaluate text classification on the test text dataset
text_true = test_df['category'].tolist()
text_pred = [ecosort_assistant.classify_text(desc) for desc in test_df['description']]

# Performance metrics for text classification
print(f"Total text samples: {len(text_true)}")
print("\nText Classification Report:")
print(classification_report(text_true, text_pred, target_names=ecosort_assistant.label_encoder.classes_))

# Confusion matrix for text classification
cm_text = confusion_matrix(text_true, text_pred, labels=ecosort_assistant.label_encoder.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_text, display_labels=ecosort_assistant.label_encoder.classes_)
plt.figure(figsize=(8,6))
disp.plot(xticks_rotation=45)
plt.title("Text Classification Confusion Matrix")
plt.show()
# Out:
# First file path: ./realwaste-main/realwaste/Paper/Paper_259.jpg
# Does it exist? True
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 11
#       8 print("Does it exist?", os.path.isfile(test_image_df['filepath'].iloc[0]))
#      10 # Try a single image to debug
# ---> 11 print("Single prediction:", ecosort_assistant.classify_image(test_image_df['filepath'].iloc[0]))
#      13 # Now do all images
#      17 image_true = test_image_df['category'].tolist()
#
# Cell In[91], line 14, in EcoSortAssistant.classify_image(self, image)
#      12 def classify_image(self, image):
#      13     img_input = self.preprocess_image(image)
# ---> 14     preds = self.image_model.predict(img_input)
#      15     class_idx = np.argmax(preds, axis=1)[0]
#      16     category = self.label_encoder.inverse_transform([class_idx])[0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1940, in Module.__getattr__(self, name)
#    1938     if name in modules:
#    1939         return modules[name]
# -> 1940 raise AttributeError(
#    1941     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1942 )
#
# AttributeError: 'GPT2LMHeadModel' object has no attribute 'predict'

# %% [markdown]
# ## Submission Guidelines
#
# 1. Make sure all code cells are properly commented and annotated
# 2. Ensure that all functions are implemented and working correctly
# 3. Verify that all evaluation metrics are calculated and analyzed
# 4. Double-check that the integrated system works as expected
# 5. Submit your completed and annotated Jupyter notebook file
#
# Remember to demonstrate your understanding of the underlying concepts and provide justification for your design decisions throughout the notebook.
